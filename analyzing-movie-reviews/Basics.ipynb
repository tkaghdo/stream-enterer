# %%
import pandas as pd
movies = pd.read_csv("fandango_score_comparison.csv")
movies
# Out:
#                                                FILM  RottenTomatoes  \
# 0                    Avengers: Age of Ultron (2015)              74
# 1                                 Cinderella (2015)              85
# 2                                    Ant-Man (2015)              80
# 3                            Do You Believe? (2015)              18
# 4                     Hot Tub Time Machine 2 (2015)              14
# 5                          The Water Diviner (2015)              63
# 6                             Irrational Man (2015)              42
# 7                                   Top Five (2014)              86
# 8                      Shaun the Sheep Movie (2015)              99
# 9                               Love & Mercy (2015)              89
# 10                Far From The Madding Crowd (2015)              84
# 11                                 Black Sea (2015)              82
# 12                                 Leviathan (2014)              99
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
movies.hist("Fandango_Stars")
movies.hist("Metacritic_norm_round")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fefa44c5860>]], dtype=object)

# %%
mean_fandango_stars = movies["Fandango_Stars"].mean()
mean_fandango_stars
# Out:
# 4.0890410958904111

# %%
mean_metacritic_norm_round = movies["Metacritic_norm_round"].mean()
mean_metacritic_norm_round
# Out:
# 2.9726027397260273

# %%
median_fandango_stars = movies["Fandango_Stars"].median()
median_fandango_stars
# Out:
# 4.0

# %%
median_metacritic_norm_round = movies["Metacritic_norm_round"].median()
median_metacritic_norm_round
# Out:
# 3.0

# %%
import numpy as np
std_fandango_stars = np.std(movies["Fandango_Stars"])
std_fandango_stars
# Out:
# 0.53853216126995307

# %%
std_metacritic_norm_round = np.std(movies["Metacritic_norm_round"])
std_metacritic_norm_round
# Out:
# 0.98756102970386306

# %%
plt.scatter(movies["Fandango_Stars"],movies["Metacritic_norm_round"])

# %%
movies["fm_diff"] = np.abs(movies["Metacritic_norm_round"] - movies["Fandango_Stars"])

# %%
movies.sort_values(by="fm_diff", ascending=False)
# Out:
#                                                 FILM  RottenTomatoes  \
# 3                             Do You Believe? (2015)              18
# 85                                 Little Boy (2015)              20
# 47                                      Annie (2014)              27
# 19                                     Pixels (2015)              17
# 134                          The Longest Ride (2015)              31
# 133                    Paul Blart: Mall Cop 2 (2015)               5
# 35                                   The Loft (2015)              11
# 15                                    Taken 3 (2015)               9
# 125                        The Wedding Ringer (2015)              27
# 51                                  Entourage (2015)              32
# 98                                   Get Hard (2015)              29
# 46            The Divergent Series: Insurgent (2015)              30
# 33                          The Boy Next Door (2015)              10
# ...

# %%
import scipy

# %%
from scipy.stats import pearsonr

r_value, p_value = pearsonr(movies["Fandango_Stars"], movies["Metacritic_norm_round"])

# %%
r_value
# Out:
# 0.17844919073895918

# %%
from scipy.stats import linregress

slope, intercept, r_value, p_value, stderr_slope = linregress(movies["Metacritic_norm_round"], movies["Fandango_Stars"])

# %%
pred = 3 * slope + intercept

pred
# Out:
# 4.0917071528212041

# %%
pred2 = 4 * slope + intercept

pred2

# %%
plt.scatter(movies["Metacritic_norm_round"],movies["Fandango_Stars"])
plt.plot([3.0, 4.0], [pred, pred2])
plt.show()
